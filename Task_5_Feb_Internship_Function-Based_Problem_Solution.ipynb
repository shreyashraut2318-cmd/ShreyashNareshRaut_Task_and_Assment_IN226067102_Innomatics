# %% [markdown]
# Problem 1: Social Media – Post Engagement Analyzer
# Problem Statement
# Create a function to analyze engagement on a social media post.
#
# Rules
# Calculate total likes
# If Total Likes ≥ 1000 → Viral Post
# Otherwise → Normal Engagement
#
# Real-Time Use
# Social media analytics platforms
# Marketing dashboards
#
# Expected Output Format
# Total Likes: 1050
# Post Status: Viral Post

# %%
# Function: Analyze engagement on a social media post
def Analyze_Post_Engagement():
    n = int(input("Enter number of posts: "))
    # Empty List
    likes = []
    
    # Taking likes input dynamically
    for i in range(n):
        like = int(input(f"Enter likes for post {i+1}: "))
        likes.append(like)

    Total_likes = sum(likes)

    if (Total_likes >= 1000):
        Status = "Viral Post"
    else:
        Status = "Normal Engagement"

    print("Total Likes:", Total_likes)
    print("Post Status:", Status)

# Function Call
Analyze_Post_Engagement()
# Out:
# Enter number of posts:  1
# Enter likes for post 1:  7667
# Total Likes: 7667
# Post Status: Viral Post

# %% [markdown]
# Problem 2: Healthcare – Medicine Stock Alert System
# Problem Statement
# Create a function to monitor medicine stock levels.
#
# Rules
# Stock < 10 → Low Stock Alert
# Stock ≥ 10 → Stock Sufficient
#
# Real-Time Use
# Pharmacy management systems
# Hospital inventory tracking
#
# Expected Output Format
# Medicine Stock: 6
# Status: Low Stock Alert

# %%
# Function: monitor medicine stock
def Check_Med_Stock():
    Stock = int(input("Enter the current medicine stock: "))

    if (Stock < 10):
        Status = "Low Stock Alert"
    else:
        Status = "Stock Sufficient"

    print("Medicine Stock:", Stock)
    print("Status:", Status)

# Function Call
Check_Med_Stock()
# Out:
# Enter the current medicine stock:  78
# Medicine Stock: 78
# Status: Stock Sufficient

# %% [markdown]
# Problem 3: Agriculture – Rainfall Adequacy Checker
# Problem Statement
# Create a function that analyzes seasonal rainfall data.
#
# Rules
# Calculate average rainfall
# Average ≥ required level → Adequate Rainfall
# Otherwise → Inadequate Rainfall
#
# Real-Time Use
# Climate monitoring systems
# Irrigation planning tools
#
# Expected Output Format
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %%
# Function: Analyze Rainfall data
def Check_Rainfall():
    n = int(input("Enter the number of rainfall records: "))
    
    Rainfall_data = []
    
    for i in range(n):
        Rain = float(input(f"Enter rainfall value {i+1}: "))
        Rainfall_data.append(Rain)

    Required_level = float(input("Enter the required rainfall level: "))

    Average = sum(Rainfall_data) / len(Rainfall_data)

    if (Average >= Required_level):
        Status = "Adequate Rainfall"
    else:
        Status = "Inadequate Rainfall"

    print("Average Rainfall:", Average)
    print("Rainfall Status:", Status)

# Function Call
Check_Rainfall()
# Out:
# Enter the number of rainfall records:  2
# Enter rainfall value 1:  899
# Enter rainfall value 2:  29202
# Enter the required rainfall level:  999
# Average Rainfall: 15050.5
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# Problem 4: Social Media – Duplicate Account Detection
# Problem Statement
# Create a function to detect duplicate usernames in a system.
#
# Rules
# If duplicates exist → Flag accounts
# Else → Accounts are unique
# Real-Time Use
# Platform moderation
# Fraud detection systems
#
# Expected Output Format
# Duplicate Accounts Found: Yes

# %%
# Function: Detect Duplicate Usernames
def Detect_Duplicate_Accounts():
    n = int(input("Enter number of Usernames: "))
    # Empty List
    Usernames = []
    
    for i in range(n):
        name = input(f"Enter username {i+1}: ")
        Usernames.append(name)

    if len(Usernames) != len(set(Usernames)):
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")

# Function Call
Detect_Duplicate_Accounts()
# Out:
# Enter number of Usernames:  3
# Enter username 1:  hh
# Enter username 2:  ghj
# Enter username 3:  gvygbuk
# Duplicate Accounts Found: No

# %% [markdown]
# Problem 5: Healthcare – Appointment Eligibility Checker
# Problem Statement
# Create a function to check whether a patient is eligible for an appointment slot.
#
# Rules
# Age ≥ 18 → Eligible
# Age < 18 → Not Eligible
# Real-Time Use
# Hospital appointment systems
# Healthcare portals
#
# Expected Output Format
# Patient Age: 21
# Eligibility Status: Eligible

# %%
# Function: Check Patient Eligibility
def Check_Appointment_Eligibility():
    Age = int(input("Enter patient age: "))

    if (Age >= 18):
        Status = "Eligible"
    else:
        Status = "Not Eligible"

    print("Patient Age:", Age)
    print("Eligibility Status:", Status)

# Function Call
Check_Appointment_Eligibility()
# Out:
# Enter patient age:  66
# Patient Age: 66
# Eligibility Status: Eligible

# %% [markdown]
# Problem 6: Agriculture – Premium Crop Price Filter
# Problem Statement
# Create a function that filters crop prices above a premium threshold.
#
# Rules
# Price > ₹2000 → Premium Crop
# Else → Regular Crop
# Real-Time Use
# Market analytics
# Export pricing systems
#
# Expected Output Format
# Premium Crops: [2500, 3200]

# %%
# Function: Filter Premium Crop Prices
def Filter_Premium_Crop_Prices():
    n = int(input("Enter number of crop prices: "))
    # Empty List
    Prices = []
    
    for i in range(n):
        price = float(input(f"Enter price {i+1}: "))
        Prices.append(price)

    Premium = []

    for price in Prices:
        if price > 2000:
            Premium.append(price)

    print("Premium Crops:", Premium)

# Function Call
Filter_Premium_Crop_Prices()
# Out:
# Enter number of crop prices:  2
# Enter price 1:  3909320
# Enter price 2:  282
# Premium Crops: [3909320.0]

# %% [markdown]
# Problem 7: System Monitoring – Application Health Checker
# Problem Statement
# Create a function to evaluate application health based on error count.
#
# Rules
# Errors = 0 → Healthy
# Errors ≤ 5 → Minor Issues
# Errors > 5 → Critical Issues
# Real-Time Use
# System monitoring tools
# IT operations dashboards
#
# Expected Output Format
# Error Count: 7
# System Status: Critical Issues

# %%
# Function: Evaluate Application Health
def Check_System_Health():
    Errors = int(input("Enter error count: "))

    if (Errors == 0):
        Status = "Healthy"
    elif (Errors <= 5):
        Status = "Minor Issues"
    else:
        Status = "Critical Issues"

    print("Error Count:", Errors)
    print("System Status:", Status)

# Function Call
Check_System_Health()
# Out:
# Enter error count:  1
# Error Count: 1
# System Status: Minor Issues

# %% [markdown]
# Problem 8: Banking – Daily Transaction Limit Checker
# Problem Statement
# Create a function to validate daily transaction amount.
#
# Rules
# Daily limit = ₹50,000
# Amount within limit → Approved
# Amount exceeds limit → Rejected
# Real-Time Use
# Banking systems
# Fraud prevention systems
#
# Expected Output Format
# Transaction Amount: 60000
# Transaction Status: Rejected

# %%
# Function: Validate Daily Transactions
def Check_Transactions():
    Amount = float(input("Enter transaction amount: "))
    Daily_limit = 50000

    if (Amount <= Daily_limit):
        Status = "Approved"
    else:
        Status = "Rejected"

    print("Transaction Amount:", Amount)
    print("Transaction Status:", Status)

# Function Call
Check_Transactions()
# Out:
# Enter transaction amount:  60000
# Transaction Amount: 60000.0
# Transaction Status: Rejected

# %% [markdown]
# Problem 9: E-Learning – Student Attendance Eligibility System
# Problem Statement
# Create a function to calculate attendance percentage and check exam eligibility.
#
# Rules
# Attendance ≥ 75% → Eligible
# Attendance < 75% → Not Eligible
# Real-Time Use
# Learning management systems
# Internship tracking platforms
#
# Expected Output Format
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %%
# Function: Calculate Attendance and Checking an Eligibility
def Check_Attendance():
    Total_classes = int(input("Enter total number of classes: "))
    Attended = 0

    for i in range(Total_classes):
        Status = input(f"Enter status for class {i+1} (Present/Absent): ")
        if Status.lower() == "present":
            Attended += 1

    Percentage = (Attended / Total_classes) * 100

    if (Percentage >= 75):
        Eligibility = "Eligible"
    else:
        Eligibility = "Not Eligible"

    print("Attendance Percentage:", Percentage)
    print("Exam Eligibility:", Eligibility)

# Function Call
Check_Attendance()
# Out:
# Enter total number of classes:  5
# Enter status for class 1 (Present/Absent):  present
# Enter status for class 2 (Present/Absent):  absent
# Enter status for class 3 (Present/Absent):  present
# Enter status for class 4 (Present/Absent):  present
# Enter status for class 5 (Present/Absent):  absent
# Attendance Percentage: 60.0
# Exam Eligibility: Not Eligible

# %% [markdown]
# Problem 10: Smart Electricity Bill Analyzer
# Problem Statement
# You are building a smart electricity billing system for residential users.
# Create a function that calculates the electricity bill and classifies usage level based on units consumed.
# Billing Rules
# First 100 units → ₹3 per unit
# Next 100 units (101–200) → ₹5 per unit
# Above 200 units → ₹7 per unit
# Usage Classification
# Total bill < ₹500 → Low Usage
# ₹500 – ₹1500 → Moderate Usage
# ₹1500 → High Usage
#
# Real-Time Use
# Smart meter systems
# Electricity board billing software
# Energy consumption analytics

# %%
# Function: Calculate Electricity bill
def Calculate_electricity_bill():
    Units = float(input("Enter number of Units Consumed: "))
    Bill = 0

    if (Units <= 100):
        Bill = Units * 3
    elif (Units <= 200):
        Bill = (100 * 3) + ((Units - 100) * 5)
    else:
        Bill = (100 * 3) + (100 * 5) + ((Units - 200) * 7)

    # Usage classification
    if (Bill < 500):
        Usage = "Low Usage"
    elif (Bill <= 1500):
        Usage = "Moderate Usage"
    else:
        Usage = "High Usage"

    print("Total Bill:", Bill)
    print("Usage Level:", Usage)

# Function Call
Calculate_electricity_bill()
# Out:
# Enter number of Units Consumed:  5
# Total Bill: 15.0
# Usage Level: Low Usage
